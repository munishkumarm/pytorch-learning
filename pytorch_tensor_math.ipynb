# %% [markdown]
# <a href="https://colab.research.google.com/github/munishkumarm/pytorch-learning/blob/main/pytorch_tensor_math.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
