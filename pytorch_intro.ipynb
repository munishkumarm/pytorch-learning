# %% [markdown]
# <a href="https://colab.research.google.com/github/munishkumarm/pytorch-learning/blob/main/pytorch_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Munish")
# Out:
# Hello Munish

# %%
import torch
# torch
# Out:
# <module 'torch' from '/usr/local/lib/python3.12/dist-packages/torch/__init__.py'>

# %%
torch_2d = torch.randn(2,2,3)
print(torch_2d)
# Out:
# tensor([[[-2.2623, -1.3336, -0.1254],
#          [-0.7135, -0.0834, -0.5098]],
#
#         [[ 0.0609, -1.0440, -1.2466],
#          [-0.5209, -1.4036,  0.1674]]])

# %% [markdown]
# torch.randn(2,2,3) : first 2 refers to row, second 2 refers to row and then 3 refers to columns

# %%
torch_4d = torch.randn(2,3,4,5)
torch_4d
# Out:
# tensor([[[[-1.6482,  0.8668,  0.4473, -1.5114, -0.3703],
#           [ 1.3478,  1.0215, -0.6026, -0.5870,  0.7417],
#           [-1.2804,  0.3271, -1.0482,  0.7214, -1.1101],
#           [-1.6681,  0.4764, -0.4324, -0.4108, -0.5850]],
#
#          [[-0.6150, -0.2176,  0.4281,  0.1416, -1.5193],
#           [ 0.6818,  0.2617, -0.7068,  0.8562, -1.4359],
#           [-0.7129, -1.2938,  0.5775,  1.5263, -0.7472],
#           [-0.5156, -0.9771, -0.6810, -1.3307, -1.0005]],
#
#          [[ 1.3249, -2.2964,  0.9901, -1.4020,  0.7850],
#           [-0.7336,  0.9696, -0.7681, -0.7902,  0.4972],
#           [-0.0734,  0.6393, -0.6708, -1.2660, -0.2520],
#           [ 0.4552, -0.8149, -0.5649,  1.2853, -0.6703]]],
#
#
#         [[[ 1.0733,  1.7720, -0.3179, -1.5618, -0.5102],
#           [-0.2476,  0.3247,  0.1482,  0.1264,  0.1538],
#           [ 1.2181,  0.0276,  2.4041, -0.3802, -0.3829],
#           [ 0.2463,  0.2193,  0.8871, -1.8635, -0.0115]],
#
# ...
